# %% [markdown]
# <a href="https://colab.research.google.com/github/sznajder/ON-Minicurso-de-ML-2022/blob/main/LSTM%26GRU_Keras_stockprediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LSTM or GRU implemented in Keras for Stock Prediction ( Time Series )

# %% [markdown]
# **Get NASDAQ data ( https://finance.yahoo.com/quote/GOOG/history/ ) loaded in a Pandas Dataframe**

# %%
# import all libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# mount Google Drive to access Data
# !fusermount -u drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# !ls "gdrive/My Drive/Colab Notebooks/"

# Get NASDAQ data ( https://finance.yahoo.com/quote/GOOG/history/ ) loaded in a Pandas Dataframe
stock_data = pd.read_csv("gdrive/My Drive/Colab Notebooks/GOOG.csv")
stock_data.info()
# Out:
# fusermount: failed to unmount /content/drive: No such file or directory
# Mounted at /content/gdrive
#  Advanced_PDE_solving.ipynb
#  AE_AnomalyDetectio_TFKeras.ipynb
#  AE_MNIST_Keras.ipynb
#  AE_PyTorch.ipynb
#  Analysis_IN.ipynb
#  analysis.ipynb
#  AnomalyDetectionStudyToy.ipynb
# 'AutoDiff_numpy (1).ipynb'
#  AutoDiff_numpy.ipynb
#  AutodiffTutorial_LHeinrich_PyHep2020.ipynb
#  Basic_PDE_solving.ipynb
#  Bayesian_hyperparameter_optimization.ipynb
#  BetheBlochEquation.ipynb
#  Building_Perceptron_from_scratch.ipynb
#  CAE_Denoising_Keras.ipynb
#  CAE_PyTorch.ipynb
#  CentralLimit.ipynb
#  classifier_MLP_FelipeFreitas.ipynb
#  Classifier_PyTorch_FelipeFreitas.ipynb
#  CNN_MNIST_Keras_sigmoid.ipynb
#  CNN_MNIST_Keras_softmax.ipynb
#  CNN_PyTorch.ipynb
#  CNPq_df.ipynb
#  Convert_Delphes2CSV_FelipeFreitas.ipynb
#  Convolution_padding_stride.ipynb
# 'Copy of AE_Keras.ipynb'
# 'Copy of convmixer'
# 'Copy of Image QGPT2.ipynb'
# 'Copy of mlp_image_classification'
# 'Copy of MLP_MNIST_Keras_new.ipynb'
#  CreatJetGraphs_NetworkX_FelipeFreitas.ipynb
#  DAE_MNIST_Keras.ipynb
#  DAE_PyTorch.ipynb
#  Data
#  Deepmind_GraphNetsBasics.ipynb
#  DiHiggs_JPata.ipynb
#  EMTF++_description.ipynb
#  emtfpp_description.ipynb
#  Expanding_MLP_MNIST_Keras_softmax.ipynb
#  FwdMuonGCNHitClassifier.ipynb
#  FwdMuonGCNSegClassifier.ipynb
#  FwdMuonGraphConstruction.ipynb
#  FwdMuonMPGNNClassifier.ipynb
#  FwdMuonMPGNNWeightedHitClassifier.ipynb
#  GAN_Keras_gauss.ipynb
#  GAN-keras-mnist-DCGAN.ipynb
# 'GAN-keras-mnist-MLP (1).ipynb'
#  GAN-keras-mnist-MLP.ipynb
#  GAN_keras_upscaling.ipynb
# 'GAN_MLP_MNIST_Keras (1).ipynb'
#  GAN_MLP_MNIST_Keras.ipynb
#  GAN_mnist_keras.ipynb
#  GAN_PyTorch.ipynb
# 'Garnet&Gravnet&DGCN_ComparisonPaper.ipynb'
# 'GarNet&GravNet_JetTagging_TFlow.ipynb'
#  GarNet_JetTagging_TFKeras.ipynb
#  Garnet_TFKeras.ipynb
#  GCN_Dgl.ipynb
#  GCN_message_passing_Numpy.ipynb
#  GCN_MNIST_TFKeras_Spektral.ipynb
#  GCN_MoleculeClassification_PytorchGeom.ipynb
# 'GCN_UnderstandingKipf&WellingPropagationRule.ipynb'
#  GCN_Unsing_Numpy.ipynb
#  GOOG.csv
#  GPT_QML_FelipeFreitas.ipynb
# 'graph data root (1).ipynb'
#  graphDataRoot_FelipeFreitas.ipynb
# 'graph data root.ipynb'
#  GraphNetLibraryTutorial.ipynb
#  GraphNeuralNets.ipynb
#  GraphPINN_Perdikaris.ipynb
#  Graph_TimeSeries_Forecasting_TFKeras_Spektral.ipynb
#  GravNet_TFKeras.ipynb
# 'HLS4ML_part1_getting_started (1).ipynb'
#  HLS4ML_part1_getting_started.ipynb
# 'HLS4ML_part2_advanced_config (1).ipynb'
#  HLS4ML_part2_advanced_config.ipynb
# 'HLS4ML_part3_compression (1).ipynb'
#  HLS4ML_part3_compression.ipynb
# 'HLS4ML_part4_quantization (1).ipynb'
#  HLS4ML_part4_quantization.ipynb
# 'HLS4ML_part5_bdt (1).ipynb'
#  HLS4ML_part5_bdt.ipynb
#  HowNNLearn-MiniNNExploration.ipynb
#  HypothesisTesting.ipynb
#  InteractionNetwork_BoostedHiggs_TFKeras.ipynb
#  JEDINet_JetIDInteractionGNN_PyTorch.ipynb
#  JetID_IteractionNetwork_PyTorch.ipynb
#  JetImages_ExploreDataset.ipynb
#  JetTagging_2DCNN_TFKeras.ipynb
#  JetTagging_DEGCN_TFKeras_Spektral.ipynb
#  JetTagging_DGCN_TFKeras_Spektral.ipynb
#  JetTagging_GAT_TFKeras_Spektral.ipynb
#  JetTagging_GCN_TFKeras.ipynb
#  JetTagging_GCN_TFKeras_Spektral.ipynb
#  JetTagging_GeneralGNN_TFKeras_Spektral.ipynb
#  JetTagging_Keras.ipynb
#  JetTagging_MLP_TFKeras.ipynb
# 'LSTM&GRU_Keras_stockprediction.ipynb'
#  LSTM_Keras_english2spanish.ipynb
#  LSTM_Keras_german2english.ipynb
#  LSTM_PyTorch.ipynb
#  MC_pi_calculation.ipynb
#  MCSamplingAndIntegration.ipynb
#  MCSimulation_3BodyDecay.ipynb
#  Medidas_de_Performance_Avaliacao_Modelos.ipynb
#  MLP_HZZ4l_Keras_sigmoid.ipynb
#  MLP_HZZ4l_Keras_softmax.ipynb
#  MLP_Keras.ipynb
#  MLP_MNIST_Keras_sigmoid.ipynb
#  MLP_MNIST_Keras_softmax.ipynb
#  MLP_MNIST_PyTorch.ipynb
#  MLP_PyTorch.ipynb
#  MLP_VBFHZZ_TFKeras_sigmoid.ipynb
#  modMLP_HZZ4l_Keras_softmax.ipynb
#  modMLP_HZZ4l_Keras_softmax_new.ipynb
#  modMLP_VBFHZZ_TFKeras_sigmoid.ipynb
#  MuonTriggerPlots.ipynb
#  Neural_ODE_PyTorch.ipynb
#  NeuralPositiveResampler_Gaussian_TFKeras.ipynb
#  NeuralPositiveResampler_TopQuarks_TFKeras.ipynb
#  OneHotEncoding.ipynb
#  ParticleNet_convert_dataset.ipynb
#  ParticleNet_TFKeras.ipynb
#  PFNET_ParticleFlowGNN_TFKeras.ipynb
# 'PhysicsAnalysisAsDifferentiablePrograming_Simpson&Heinrich_Pyhep2020.ipynb'
# 'PINN_ContinuousTimeFormulation_Perdikaris (1).ipynb'
#  PINN_ContinuousTimeFormulation_Perdikaris.ipynb
#  PINN_DiscreteTimeFormulation_Perdikaris.ipynb
#  PINN_GNN_Perdikaris.ipynb
#  PINN_PIDGM_Perdikaris.ipynb
#  Pivarski_01-using-uproot-effectively.ipynb
#  Pivarski_02-columnar-analysis-awkward-array.ipynb
#  Plot_CSC_muon_hits.ipynb
# 'Plot_FwdMuon_Hits (1).ipynb'
#  Plot_FwdMuon_Hits.ipynb
#  Plot_FwdMuon_Stubs.ipynb
#  Plotting_UsingPandas.ipynb
#  presentation_QantumImageGPT_FelipeFreitas.ipynb
#  __pycache__
#  pytorch_FelipeFreitas.ipynb
# 'PyTorch_Inference&Validation_4.ipynb'
#  PyTorch__NN_2.ipynb
#  Pytorch_spiral_classification.ipynb
#  PyTorch_Tensors_1.ipynb
#  Pytorch_Training_3.ipynb
#  QML_Binary_Classifier_DEMO.ipynb
#  QuantumComputing_basics_sum.ipynb
#  QuantumML_Binary_Classifier_AWSBraket.ipynb
#  Quantum_Simulations_AWSBraket.ipynb
#  Quantum_Simulations_Braket_Demo.ipynb
#  ResidualMLP_mnist_keras.ipynb
#  ResMLP_MNIST_Keras_softmax.ipynb
#  RNN_PyTorch.ipynb
#  ROC_uncertainty.ipynb
#  Set2Graph_GNN_PyTorch.ipynb
#  SimpleInteractionNetwork_PyTorch.ipynb
#  TF2_4_HPC.ipynb
#  TheoryBehind_NN_EDO_EDP_solutions.ipynb
#  TransferLearning_PyTorch.ipynb
#  TriggerEfficiencyMeasurement_fromNanoAODonSWAN.ipynb
#  TriggerEfficiencyMeasurement.ipynb
#  Untitled
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Uproot_loop_events.ipynb
#  Uproot_loop_events_new.ipynb
#  VAE_Keras.ipynb
#  VAE_MNIST_Keras.ipynb
#  VAE_PyTorch.ipynb
#  VBF_exercise.ipynb
#  VBS_WW_GAT_TFKeras_Spektral.ipynb
#  VectorialOperations.ipynb
#  Visualizing_transformations.ipynb
#  Vitor_FwdMuonMPGNNHitClassifier.ipynb
#  WWanalysis_CSVplots.ipynb
#  YHaddad_dijet_GradientBoostClassifier_SKLearn.ipynb
#  Zpeak_PyLHE.ipynb
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1258 non-null   object
#  1   Open       1258 non-null   float64
#  2   High       1258 non-null   float64
#  3   Low        1258 non-null   float64
#  4   Close      1258 non-null   float64
#  5   Adj Close  1258 non-null   float64
#  6   Volume     1258 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 68.9+ KB

# %% [markdown]
# **We will take the average of the low and high of the Google stock for the day and volume of the stocks traded for the day to predict the stock prices.**

# %%
import math

# take the average of the low and high of the Google stock for the day
stock_data["average"] = (stock_data["High"] + stock_data["Low"])/2
print(stock_data.head())

# take the volume and average stock price as our input features and store it in input_data list
input_feature= stock_data.iloc[:,[6,7]].values
input_data = input_feature
print("Input data shape:",input_data.shape)

# plot the data for volume for the Google stocks traded for the day
plt.plot(input_feature[:,0])
plt.title("Volume of stocks sold")
plt.xlabel("Time (latest-> oldest)")
plt.ylabel("Volume of stocks traded")
plt.show()


# plot the data for the average price for the day the Google stock
plt.plot(input_feature[:,1], color='blue')
plt.title("Google Stock Prices")
plt.xlabel("Time (latest-> oldest)")
plt.ylabel("Stock Opening Price")
plt.show()

# Normalizing the input data using MinMaxScaler so that all the input features are on the scale from 0 to 1
from sklearn.preprocessing import MinMaxScaler
sc= MinMaxScaler(feature_range=(0,1))
input_data[:,0:2] = sc.fit_transform(input_feature[:,:])
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2014-09-26  574.482788  577.664001  573.086609  575.519897  575.519897
# 1  2014-09-29  570.184570  576.606934  569.606140  574.781921  574.781921
# 2  2014-09-30  575.350403  578.262390  571.281555  575.779175  575.779175
# 3  2014-10-01  574.432922  575.998596  565.457520  566.714111  566.714111
# 4  2014-10-02  565.756714  570.344116  561.777649  568.519104  568.519104
#
#     Volume     average
# 0  1443600  575.375305
# 1  1282400  573.106537
# 2  1621700  574.771972
# 3  1445400  570.728058
# 4  1178400  566.060882
# Input data shape: (1258, 2)

# %% [markdown]
# **The input to every LSTM layer must be in a 3D format. The three dimensions of this input are:**
# *   **Samples:** one sequence is one sample and a batch is comprised of one or more samples
# *   **Time Steps:** one time step is one point of observation in the sample
# *   **Features:** one feature is one observation at a time step
#
# **This means that the input layer expects a 3D array of data when fitting the model and when making predictions, even if specific dimensions of the array contain a single value ( e.g. one sample or one feature ). The input layer of your LSTM network assumes you have 1 or more samples and requires that you specify the number of time steps and the number of features. This is specifyied as a tuple to the input_shape argument.**
#
#
#
#
# ---
#
#
# For more information see https://machinelearningmastery.com/reshape-input-data-long-short-term-memory-networks-keras/
#
#
#
#
# ---

# %% [markdown]
# **We need to put the LSTM input data in the form (Volume of stocks traded, Average stock price). We also need to create a time series containing this data for past 50 days and the target variable that will be Google’s daily stock price.**

# %%
# Rescale data to [0,1] interval to make it easier to train the NN
#from sklearn.preprocessing import MinMaxScaler
#sc = MinMaxScaler(feature_range = (0, 1))
#input_data = sc.fit_transform(input_data)

# Create the time series with lengh given by LOOKBACK
lookback= 30

test_size=int(.3 * len(stock_data))
X=[]
y=[]
for i in range(len(stock_data)-lookback-1):
    t=[]
    for j in range(0,lookback):        
        t.append(input_data[[(i+j)], :])
    X.append(t)
    y.append(input_data[i+ lookback,1])

# %% [markdown]
# **The input data 3D format is (sample size, time steps, no. of input features).  In our case timesteps is given by LOOKBACK and the number of input features is 2 (volume of stocks traded and the average stock price).**

# %%
X, y= np.array(X), np.array(y)
#X_test = X[:test_size+lookback]
####### My mods to separate trainig from test data
#X_test = X[len(stock_data)-test_size-lookback:len(stock_data)]
X_test = X[len(stock_data)-lookback-test_size:len(stock_data)-lookback]
print("init=",len(stock_data)-lookback-test_size)
print("end=",len(stock_data)-lookback)
print("end=",len(stock_data))
X=X[0:len(stock_data)-lookback-test_size]
y=y[0:len(stock_data)-lookback-test_size]
#######
X = X.reshape(X.shape[0],lookback, 2)
X_test = X_test.reshape(X_test.shape[0],lookback, 2)

# Print dimension of the training data and test data: No. of sample, time steps and no. of input features
print("Total number of days:",len(stock_data))
print("X=",X.shape)
print("X_test=",X_test.shape)
print("y=",y.shape[0])
# Out:
# init= 851
# end= 1228
# end= 1258
# Total number of days: 1258
# X= (851, 30, 2)
# X_test= (376, 30, 2)
# y= 851

# %% [markdown]
# **Build the LSTM**

# %%
from keras import Sequential
from keras.layers import Dense, LSTM , GRU

# define the LSTM architecture 
model = Sequential()
#model.add(LSTM(units=30, input_shape=(X.shape[1],2)))
model.add(GRU(units=30, input_shape=(X.shape[1],2)))
model.add(Dense(units=1,activation='linear'))
model.summary()

# compile 
#model.compile(optimizer='adam', loss='mean_squared_error', metrics=["mean_squared_error"])
model.compile(optimizer='adam', loss='mean_squared_error')
# train the network
history = model.fit(X, y, epochs=10, batch_size=32 , verbose=1 , validation_split=0.2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 30)                3060
#
#  dense (Dense)               (None, 1)                 31
#
# =================================================================
# Total params: 3,091
# Trainable params: 3,091
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 22/22 [==============================] - 7s 22ms/step - loss: 0.0527 - val_loss: 0.0647
# Epoch 2/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0117 - val_loss: 0.0450
# Epoch 3/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0064 - val_loss: 0.0212
# Epoch 4/10
# 22/22 [==============================] - 0s 6ms/step - loss: 0.0027 - val_loss: 0.0065
# Epoch 5/10
# 22/22 [==============================] - 0s 6ms/step - loss: 8.4426e-04 - val_loss: 6.9440e-04
# Epoch 6/10
# 22/22 [==============================] - 0s 6ms/step - loss: 5.2305e-04 - val_loss: 8.0816e-04
# Epoch 7/10
# 22/22 [==============================] - 0s 6ms/step - loss: 4.3976e-04 - val_loss: 7.0269e-04
# Epoch 8/10
# 22/22 [==============================] - 0s 6ms/step - loss: 3.9249e-04 - val_loss: 7.2373e-04
# Epoch 9/10
# 22/22 [==============================] - 0s 6ms/step - loss: 3.7348e-04 - val_loss: 7.6511e-04
# Epoch 10/10
# 22/22 [==============================] - 0s 5ms/step - loss: 3.4881e-04 - val_loss: 8.6940e-04

# %% [markdown]
# **Make predictions and plot performance**

# %%
# make predictions
Y_test = model.predict(X_test)

# Remove normalization by going back to original range of stock values
#Y_test=sc.inverse_transform(Y_test)
#input_data=sc.inverse_transform(input_data)

# plot the predictions
plt.plot(Y_test, color= 'red')
plt.plot(X_test[:,-1,1], color='green')
plt.title("Stock Prediction")
plt.xlabel("Time (latest-> oldest)")
plt.ylabel("Stock Average Price")
plt.show()

# plot performance
plt.style.use('default')
plt.figure(figsize=(10,7))

ax = plt.subplot(2, 2, 1)
ax.plot(history.history['loss'], label='loss')
ax.plot(history.history['val_loss'], label='val_loss')
ax.set_ylim([0, 0.1])
ax.legend(loc="upper right")
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')
